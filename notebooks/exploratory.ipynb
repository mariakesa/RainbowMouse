# %%
import os

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

from allensdk.brain_observatory.ecephys.ecephys_project_cache import EcephysProjectCache

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
output_dir=os.environ["ALLEN_CACHE"]
manifest_path = os.path.join(output_dir, "manifest.json")

cache = EcephysProjectCache.from_warehouse(manifest=manifest_path)
sessions = cache.get_session_table()

session = cache.get_session_data(sessions.index.values[0])

session

stimuli=session.stimulus_presentations

stimuli
# Out:
#                          stimulus_block   start_time    stop_time  \
# stimulus_presentation_id
# 0                                  null    13.470683    73.537433
# 1                                   0.0    73.537433    73.770952
# 2                                   0.0    73.770952    74.021150
# 3                                   0.0    74.021150    74.271349
# 4                                   0.0    74.271349    74.521547
# ...                                 ...          ...          ...
# 70383                              14.0  9133.889309  9134.139517
# 70384                              14.0  9134.139517  9134.389719
# 70385                              14.0  9134.389719  9134.639920
# 70386                              14.0  9134.639920  9134.890122
# 70387                              14.0  9134.890122  9135.140323
#
#                             stimulus_name temporal_frequency y_position  \
# stimulus_presentation_id
# 0                             spontaneous               null       null
# 1                                  gabors                4.0       30.0
# 2                                  gabors                4.0      -10.0
# 3                                  gabors                4.0       20.0
# 4                                  gabors                4.0      -40.0
# ...                                   ...                ...        ...
# 70383                     static_gratings               null       null
# 70384                     static_gratings               null       null
# 70385                     static_gratings               null       null
# 70386                     static_gratings               null       null
# 70387                     static_gratings               null       null
#
#                          spatial_frequency color  \
# stimulus_presentation_id
# 0                                     null  null
# 1                                     0.08  null
# 2                                     0.08  null
# 3                                     0.08  null
# 4                                     0.08  null
# ...                                    ...   ...
# 70383                                 0.04  null
# 70384                                 0.02  null
# 70385                                 0.08  null
# 70386                                 0.32  null
# 70387                                 0.16  null
#
#                                                    phase x_position  \
# stimulus_presentation_id
# 0                                                   null       null
# 1                         [3644.93333333, 3644.93333333]        0.0
# 2                         [3644.93333333, 3644.93333333]      -30.0
# 3                         [3644.93333333, 3644.93333333]       10.0
# 4                         [3644.93333333, 3644.93333333]      -40.0
# ...                                                  ...        ...
# 70383                                               0.75       null
# 70384                                                0.0       null
# 70385                                                0.0       null
# 70386                                                0.5       null
# 70387                                                0.0       null
#
#                                     size orientation contrast frame  \
# stimulus_presentation_id
# 0                                   null        null     null  null
# 1                           [20.0, 20.0]        45.0      0.8  null
# 2                           [20.0, 20.0]         0.0      0.8  null
# 3                           [20.0, 20.0]        45.0      0.8  null
# 4                           [20.0, 20.0]         0.0      0.8  null
# ...                                  ...         ...      ...   ...
# 70383                     [250.0, 250.0]        60.0      0.8  null
# 70384                     [250.0, 250.0]        90.0      0.8  null
# 70385                     [250.0, 250.0]        60.0      0.8  null
# 70386                     [250.0, 250.0]        60.0      0.8  null
# 70387                     [250.0, 250.0]        60.0      0.8  null
#
#                            duration  stimulus_condition_id
# stimulus_presentation_id
# 0                         60.066750                      0
# 1                          0.233519                      1
# 2                          0.250199                      2
# 3                          0.250199                      3
# 4                          0.250199                      4
# ...                             ...                    ...
# 70383                      0.250209                   4886
# 70384                      0.250201                   4806
# 70385                      0.250201                   4874
# 70386                      0.250201                   4789
# 70387                      0.250201                   4809
#
# [70388 rows x 16 columns]

# %%
stimuli.stimulus_name.unique()
# Out:
# array(['spontaneous', 'gabors', 'flashes', 'drifting_gratings',
#        'natural_movie_three', 'natural_movie_one', 'static_gratings',
#        'natural_scenes'], dtype=object)

# %%
from collections import Counter

Counter(stimuli[stimuli.stimulus_name == "natural_scenes"].frame)#.stimulus_block.unique()
# Out:
# 0

# %%
5950/(50)
# Out:
# 119.0

# %%
probe_id = session.probes[session.probes.description == 'probeE'].index.values[0]

lfp = session.get_lfp(probe_id)
# Out:
# WARNING:root:downloading a 2345.194MiB file from http://api.brain-map.org//api/v2/well_known_file_download/1026124475
# Downloading: 100%|██████████| 2.46G/2.46G [11:53<00:00, 3.45MB/s]
