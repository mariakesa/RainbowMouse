# %%
import numpy as np

print(np.load("/home/maria/Documents/RainbowMouseCache/lfp_multi.npy").sum())
# Out:
# nan

# %%
import numpy as np

lfp = np.load("/home/maria/Documents/RainbowMouseCache/lfp_multi.npy")

n_nans = np.isnan(lfp).sum()
print(f"Total NaNs in LFP array: {n_nans}")
# Out:
# Total NaNs in LFP array: 68495

# %%
lfp.shape
# Out:
# (516, 5900)

# %%
516*5900
# Out:
# 3044400

# %%
import matplotlib.pyplot as plt
plt.imshow(lfp, aspect='auto', interpolation='nearest')
